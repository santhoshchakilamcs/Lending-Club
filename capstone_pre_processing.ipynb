# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('LoanStats3a.csv')

# %%
df.head()
# Out:
#     id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  NaN        NaN     5000.0       5000.0           4975.0   36 months
# 1  NaN        NaN     2500.0       2500.0           2500.0   60 months
# 2  NaN        NaN     2400.0       2400.0           2400.0   36 months
# 3  NaN        NaN    10000.0      10000.0          10000.0   36 months
# 4  NaN        NaN     3000.0       3000.0           3000.0   60 months
#
#   int_rate  installment grade sub_grade                 emp_title emp_length  \
# 0   10.65%       162.87     B        B2                       NaN  10+ years
# 1   15.27%        59.83     C        C4                     Ryder   < 1 year
# 2   15.96%        84.33     C        C5                       NaN  10+ years
# 3   13.49%       339.31     C        C1       AIR RESOURCES BOARD  10+ years
# 4   12.69%        67.79     B        B5  University Medical Group     1 year
#
#   home_ownership  annual_inc verification_status issue_d  loan_status  \
# ...

# %%
df.shape
# Out:
# (42538, 144)

# %%
sns.heatmap(df.isnull())

# %%
df = df[df.columns[((df.isnull().sum())/42583) < 0.4]]

# %%
df.shape
# Out:
# (42538, 53)

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0     5000.0       5000.0           4975.0   36 months   10.65%       162.87
# 1     2500.0       2500.0           2500.0   60 months   15.27%        59.83
# 2     2400.0       2400.0           2400.0   36 months   15.96%        84.33
# 3    10000.0      10000.0          10000.0   36 months   13.49%       339.31
# 4     3000.0       3000.0           3000.0   60 months   12.69%        67.79
#
#   grade sub_grade                 emp_title emp_length home_ownership  \
# 0     B        B2                       NaN  10+ years           RENT
# 1     C        C4                     Ryder   < 1 year           RENT
# 2     C        C5                       NaN  10+ years           RENT
# 3     C        C1       AIR RESOURCES BOARD  10+ years           RENT
# 4     B        B5  University Medical Group     1 year           RENT
#
#    annual_inc verification_status issue_d  loan_status pymnt_plan  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42538 entries, 0 to 42537
# Data columns (total 53 columns):
# loan_amnt                     42535 non-null float64
# funded_amnt                   42535 non-null float64
# funded_amnt_inv               42535 non-null float64
# term                          42535 non-null object
# int_rate                      42535 non-null object
# installment                   42535 non-null float64
# grade                         42535 non-null object
# sub_grade                     42535 non-null object
# emp_title                     39909 non-null object
# emp_length                    41423 non-null object
# home_ownership                42535 non-null object
# annual_inc                    42531 non-null float64
# verification_status           42535 non-null object
# issue_d                       42535 non-null object
# loan_status                   42535 non-null object
# pymnt_plan                    42535 non-null object
# ...

# %%
df[:1][df.columns]
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0     5000.0       5000.0           4975.0   36 months   10.65%       162.87
#
#   grade sub_grade emp_title emp_length home_ownership  annual_inc  \
# 0     B        B2       NaN  10+ years           RENT     24000.0
#
#   verification_status issue_d loan_status pymnt_plan  \
# 0            Verified  Dec-11  Fully Paid          n
#
#                                                 desc      purpose     title  \
# 0    Borrower added on 12/22/11 > I need to upgra...  credit_card  Computer
#
#   zip_code addr_state    dti  delinq_2yrs earliest_cr_line  inq_last_6mths  \
# 0    860xx         AZ  27.65          0.0           Jan-85             1.0
#
#    open_acc  pub_rec  revol_bal revol_util  total_acc initial_list_status  \
# 0       3.0      0.0    13648.0     83.70%        9.0                   f
#
#    out_prncp  out_prncp_inv  total_pymnt  total_pymnt_inv  total_rec_prncp  \
# ...

# %%
df.term.value_counts()
# Out:
#  36 months    31534
#  60 months    11001
# Name: term, dtype: int64

# %%
df.grade.value_counts()
# Out:
# B    12389
# A    10183
# C     8740
# D     6016
# E     3394
# F     1301
# G      512
# Name: grade, dtype: int64

# %%
df.sub_grade.value_counts()
# Out:
# B3    2997
# A4    2905
# B5    2807
# A5    2793
# B4    2590
# C1    2264
# C2    2157
# B2    2113
# B1    1882
# A3    1823
# C3    1658
# A2    1520
# D2    1485
# C4    1370
# D3    1322
# C5    1291
# A1    1142
# D4    1140
# D1    1053
# D5    1016
# E1     884
# E2     791
# E3     668
# E4     552
# E5     499
# F1     392
# F2     308
# F3     236
# F4     211
# F5     154
# G1     141
# G2     107
# G4      99
# G5      86
# G3      79
# Name: sub_grade, dtype: int64

# %%
df.emp_title.value_counts()
# Out:
# US Army                                  139
# Bank of America                          115
# IBM                                       72
# AT&T                                      61
# Kaiser Permanente                         61
# UPS                                       58
# Wells Fargo                               57
# USAF                                      56
# US Air Force                              55
# Self Employed                             49
# United States Air Force                   48
# Walmart                                   47
# Lockheed Martin                           46
# State of California                       45
# Verizon Wireless                          43
# U.S. Army                                 42
# USPS                                      41
# Walgreens                                 41
# US ARMY                                   40
# Self                                      39
# JP Morgan Chase                           38
# ...

# %%
for i in df.columns[df.dtypes == 'object']:
    print(df[i].value_counts())
# Out:
#  36 months    31534
#  60 months    11001
# Name: term, dtype: int64
# 10.99%    970
# 11.49%    837
# 13.49%    832
# 7.51%     787
# 7.88%     742
# 7.49%     656
# 11.71%    609
# 9.99%     607
# 7.90%     582
# 5.42%     573
# 11.99%    535
# 12.69%    492
# 10.37%    470
# 12.99%    456
# 6.03%     447
# 8.49%     445
# 12.42%    443
# 10.65%    435
# 11.86%    418
# 5.79%     410
# 8.90%     402
# 10.59%    400
# 7.29%     397
# 6.62%     396
# 14.27%    391
# 9.63%     384
# 9.91%     377
# 12.53%    356
# 5.99%     347
# 7.14%     342
#          ...
# 19.39%      4
# 18.86%      3
# 12.62%      3
# 20.69%      3
# 24.11%      3
# 14.67%      3
# 14.57%      3
# 18.49%      3
# 16.46%      3
# 17.28%      2
# 17.59%      2
# 17.91%      2
# 16.33%      2
# 22.94%      2
# 13.84%      2
# 17.09%      2
# 21.82%      2
# 20.20%      2
# 16.20%      1
# 17.44%      1
# 17.72%      1
# 17.41%      1
# 17.46%      1
# 21.48%      1
# 17.78%      1
# 18.72%      1
# 22.64%      1
# ...

# %%
df.drop(['initial_list_status','hardship_flag','pymnt_plan','application_type','acc_now_delinq','chargeoff_within_12_mths','collection_recovery_fee','collections_12_mths_ex_med','delinq_amnt','policy_code','tax_liens'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0     5000.0       5000.0           4975.0   36 months   10.65%       162.87
# 1     2500.0       2500.0           2500.0   60 months   15.27%        59.83
# 2     2400.0       2400.0           2400.0   36 months   15.96%        84.33
# 3    10000.0      10000.0          10000.0   36 months   13.49%       339.31
# 4     3000.0       3000.0           3000.0   60 months   12.69%        67.79
#
#   grade sub_grade                 emp_title emp_length home_ownership  \
# 0     B        B2                       NaN  10+ years           RENT
# 1     C        C4                     Ryder   < 1 year           RENT
# 2     C        C5                       NaN  10+ years           RENT
# 3     C        C1       AIR RESOURCES BOARD  10+ years           RENT
# 4     B        B5  University Medical Group     1 year           RENT
#
#    annual_inc verification_status issue_d  loan_status  \
# ...

# %% [raw]
# OHE - term,grade,home_ownership,verification_status,loan_status,debt_settlement_flag
# cat - sub_grade,emp_length,addr_state,purpose,pub_rec

# %%
sns.heatmap(df.isnull())

# %%
df.isnull().sum()
# Out:
# loan_amnt                   3
# funded_amnt                 3
# funded_amnt_inv             3
# term                        3
# int_rate                    3
# installment                 3
# grade                       3
# sub_grade                   3
# emp_title                2629
# emp_length               1115
# home_ownership              3
# annual_inc                  7
# verification_status         3
# issue_d                     3
# loan_status                 3
# desc                    13296
# purpose                     3
# title                      16
# zip_code                    3
# addr_state                  3
# dti                         3
# delinq_2yrs                32
# earliest_cr_line           32
# inq_last_6mths             32
# open_acc                   32
# pub_rec                    32
# revol_bal                   3
# revol_util                 93
# total_acc                  32
# out_prncp                   3
# out_prncp_inv               3
# ...

# %%
pd.set_option('display.max_columns', None)

df.head(2)
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0     5000.0       5000.0           4975.0   36 months   10.65%       162.87
# 1     2500.0       2500.0           2500.0   60 months   15.27%        59.83
#
#   grade sub_grade emp_title emp_length home_ownership  annual_inc  \
# 0     B        B2       NaN  10+ years           RENT     24000.0
# 1     C        C4     Ryder   < 1 year           RENT     30000.0
#
#   verification_status issue_d  loan_status  \
# 0            Verified  Dec-11   Fully Paid
# 1     Source Verified  Dec-11  Charged Off
#
#                                                 desc      purpose     title  \
# 0    Borrower added on 12/22/11 > I need to upgra...  credit_card  Computer
# 1    Borrower added on 12/22/11 > I plan to use t...          car      bike
#
#   zip_code addr_state    dti  delinq_2yrs earliest_cr_line  inq_last_6mths  \
# 0    860xx         AZ  27.65          0.0           Jan-85             1.0
# ...

# %%
df.out_prncp.value_counts()
# Out:
# 0.0    42535
# Name: out_prncp, dtype: int64

# %%
df.drop(['emp_title','title','desc','zip_code'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0     5000.0       5000.0           4975.0   36 months   10.65%       162.87
# 1     2500.0       2500.0           2500.0   60 months   15.27%        59.83
# 2     2400.0       2400.0           2400.0   36 months   15.96%        84.33
# 3    10000.0      10000.0          10000.0   36 months   13.49%       339.31
# 4     3000.0       3000.0           3000.0   60 months   12.69%        67.79
#
#   grade sub_grade emp_length home_ownership  annual_inc verification_status  \
# 0     B        B2  10+ years           RENT     24000.0            Verified
# 1     C        C4   < 1 year           RENT     30000.0     Source Verified
# 2     C        C5  10+ years           RENT     12252.0        Not Verified
# 3     C        C1  10+ years           RENT     49200.0     Source Verified
# 4     B        B5     1 year           RENT     80000.0     Source Verified
#
# ...

# %%
df.shape
# Out:
# (42538, 38)

# %%
#df = df.sort_index(axis=1)
df.head(2)
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0     5000.0       5000.0           4975.0   36 months   10.65%       162.87
# 1     2500.0       2500.0           2500.0   60 months   15.27%        59.83
#
#   grade sub_grade emp_length home_ownership  annual_inc verification_status  \
# 0     B        B2  10+ years           RENT     24000.0            Verified
# 1     C        C4   < 1 year           RENT     30000.0     Source Verified
#
#   issue_d  loan_status      purpose addr_state    dti  delinq_2yrs  \
# 0  Dec-11   Fully Paid  credit_card         AZ  27.65          0.0
# 1  Dec-11  Charged Off          car         GA   1.00          0.0
#
#   earliest_cr_line  inq_last_6mths  open_acc  pub_rec  revol_bal revol_util  \
# 0           Jan-85             1.0       3.0      0.0    13648.0     83.70%
# 1           Apr-99             5.0       3.0      0.0     1687.0      9.40%
#
# ...

# %%
df[df['funded_amnt'] != df['loan_amnt']] # Both are same
# Out:
#        loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 61       17500.0       8950.0      8925.000000   60 months   17.27%
# 66       12500.0       8925.0      8925.000000   60 months   17.27%
# 70       20975.0      13575.0     13550.000000   60 months   17.58%
# 77        7250.0       7200.0      7175.000000   60 months   21.67%
# 80       35000.0      22075.0     22050.000000   60 months   17.27%
# 96       20000.0      12800.0     12775.000000   60 months   11.71%
# 124      28000.0      11800.0     11775.000000   60 months   19.91%
# 217      21000.0      11800.0     11500.000000   60 months   17.27%
# 223      24250.0      18100.0     18075.000000   60 months   23.91%
# 249      13200.0       8975.0      8975.000000   60 months   17.27%
# 268      35000.0      26825.0     26800.000000   60 months   18.64%
# 306      35000.0      23250.0     23200.000000   60 months   20.30%
# 333      20000.0      13475.0     13041.470440   60 months   10.65%
# ...

# %%
df.drop('funded_amnt',axis=1,inplace = True)

# %%
df[df['out_prncp'] != df['out_prncp_inv']] # Both are same
# Out:
#        loan_amnt  funded_amnt_inv term int_rate  installment grade sub_grade  \
# 39786        NaN              NaN  NaN      NaN          NaN   NaN       NaN
# 39787        NaN              NaN  NaN      NaN          NaN   NaN       NaN
# 39788        NaN              NaN  NaN      NaN          NaN   NaN       NaN
#
#       emp_length home_ownership  annual_inc verification_status issue_d  \
# 39786        NaN            NaN         NaN                 NaN     NaN
# 39787        NaN            NaN         NaN                 NaN     NaN
# 39788        NaN            NaN         NaN                 NaN     NaN
#
#       loan_status purpose addr_state  dti  delinq_2yrs earliest_cr_line  \
# 39786         NaN     NaN        NaN  NaN          NaN              NaN
# 39787         NaN     NaN        NaN  NaN          NaN              NaN
# 39788         NaN     NaN        NaN  NaN          NaN              NaN
#
# ...

# %%
df.drop('out_prncp_inv',axis=1,inplace = True)
df.drop('out_prncp',axis=1,inplace = True)

# %%
df[df['total_pymnt'] != df['total_pymnt_inv']].shape # Both are same
# Out:
# (38489, 35)

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt_inv        term int_rate  installment grade  \
# 0     5000.0           4975.0   36 months   10.65%       162.87     B
# 1     2500.0           2500.0   60 months   15.27%        59.83     C
# 2     2400.0           2400.0   36 months   15.96%        84.33     C
# 3    10000.0          10000.0   36 months   13.49%       339.31     C
# 4     3000.0           3000.0   60 months   12.69%        67.79     B
#
#   sub_grade emp_length home_ownership  annual_inc verification_status issue_d  \
# 0        B2  10+ years           RENT     24000.0            Verified  Dec-11
# 1        C4   < 1 year           RENT     30000.0     Source Verified  Dec-11
# 2        C5  10+ years           RENT     12252.0        Not Verified  Dec-11
# 3        C1  10+ years           RENT     49200.0     Source Verified  Dec-11
# 4        B5     1 year           RENT     80000.0     Source Verified  Dec-11
#
#    loan_status         purpose addr_state    dti  delinq_2yrs  \
# ...

# %%
sns.set(rc={'figure.figsize':(20,20)})
sns.set_style('whitegrid')

sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
df.dropna(how='all',inplace=True)

# %%
df.shape
# Out:
# (42535, 35)

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt_inv        term int_rate  installment grade  \
# 0     5000.0           4975.0   36 months   10.65%       162.87     B
# 1     2500.0           2500.0   60 months   15.27%        59.83     C
# 2     2400.0           2400.0   36 months   15.96%        84.33     C
# 3    10000.0          10000.0   36 months   13.49%       339.31     C
# 4     3000.0           3000.0   60 months   12.69%        67.79     B
#
#   sub_grade emp_length home_ownership  annual_inc verification_status issue_d  \
# 0        B2  10+ years           RENT     24000.0            Verified  Dec-11
# 1        C4   < 1 year           RENT     30000.0     Source Verified  Dec-11
# 2        C5  10+ years           RENT     12252.0        Not Verified  Dec-11
# 3        C1  10+ years           RENT     49200.0     Source Verified  Dec-11
# 4        B5     1 year           RENT     80000.0     Source Verified  Dec-11
#
#    loan_status         purpose addr_state    dti  delinq_2yrs  \
# ...

# %% [markdown]
# loan_amnt and total_pymnt,
#
# funded_amnt_inv	and total_pymnt_inv are related

# %%
df
# Out:
#        loan_amnt  funded_amnt_inv        term int_rate  installment grade  \
# 0         5000.0       4975.00000   36 months   10.65%       162.87     B
# 1         2500.0       2500.00000   60 months   15.27%        59.83     C
# 2         2400.0       2400.00000   36 months   15.96%        84.33     C
# 3        10000.0      10000.00000   36 months   13.49%       339.31     C
# 4         3000.0       3000.00000   60 months   12.69%        67.79     B
# 5         5000.0       5000.00000   36 months    7.90%       156.46     A
# 6         7000.0       7000.00000   60 months   15.96%       170.08     C
# 7         3000.0       3000.00000   36 months   18.64%       109.43     E
# 8         5600.0       5600.00000   60 months   21.28%       152.39     F
# 9         5375.0       5350.00000   60 months   12.69%       121.45     B
# 10        6500.0       6500.00000   60 months   14.65%       153.45     C
# 11       12000.0      12000.00000   36 months   12.69%       402.54     B
# ...

# %% [markdown]
# total_rec_inv = total_rec_prncp+total_rec_int+total_rec_late_fee+recoveries

# %%
df.describe()
# Out:
#           loan_amnt  funded_amnt_inv   installment    annual_inc  \
# count  42535.000000     42535.000000  42535.000000  4.253100e+04
# mean   11089.722581     10139.938785    322.623063  6.913656e+04
# std     7410.938391      7131.598014    208.927216  6.409635e+04
# min      500.000000         0.000000     15.670000  1.896000e+03
# 25%     5200.000000      4950.000000    165.520000  4.000000e+04
# 50%     9700.000000      8500.000000    277.690000  5.900000e+04
# 75%    15000.000000     14000.000000    428.180000  8.250000e+04
# max    35000.000000     35000.000000   1305.190000  6.000000e+06
#
#                 dti   delinq_2yrs  inq_last_6mths      open_acc       pub_rec  \
# count  42535.000000  42506.000000    42506.000000  42506.000000  42506.000000
# mean      13.373043      0.152449        1.081424      9.343951      0.058156
# std        6.726315      0.512406        1.527455      4.496274      0.245713
# ...

# %%
df.loan_amnt.sum()
# Out:
# 471701350.0

# %%
df.total_pymnt.sum()
# Out:
# 511288318.24875504

# %%
df.funded_amnt_inv.sum()
# Out:
# 431302296.20912087

# %%
df.total_pymnt_inv.sum()
# Out:
# 481196466.54999995

# %% [markdown]
# Find funded_amnt_inv ? (Regression problem)
#
#
# total_pymnt > loan_amnt*(1.x) then transaction is succesfull otherwise not.

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt_inv        term int_rate  installment grade  \
# 0     5000.0           4975.0   36 months   10.65%       162.87     B
# 1     2500.0           2500.0   60 months   15.27%        59.83     C
# 2     2400.0           2400.0   36 months   15.96%        84.33     C
# 3    10000.0          10000.0   36 months   13.49%       339.31     C
# 4     3000.0           3000.0   60 months   12.69%        67.79     B
#
#   sub_grade emp_length home_ownership  annual_inc verification_status issue_d  \
# 0        B2  10+ years           RENT     24000.0            Verified  Dec-11
# 1        C4   < 1 year           RENT     30000.0     Source Verified  Dec-11
# 2        C5  10+ years           RENT     12252.0        Not Verified  Dec-11
# 3        C1  10+ years           RENT     49200.0     Source Verified  Dec-11
# 4        B5     1 year           RENT     80000.0     Source Verified  Dec-11
#
#    loan_status         purpose addr_state    dti  delinq_2yrs  \
# ...

# %%
#df[['issue_d','earliest_cr_line','last_pymnt_d','last_credit_pull_d']].astype('datetime64')

# %%
# Converting to datetime columns
col = ['issue_d','earliest_cr_line','last_pymnt_d','last_credit_pull_d']
for i in col:
    df[i] = pd.to_datetime(df[i].str.upper(), format='%b-%y', yearfirst=False)

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt_inv        term int_rate  installment grade  \
# 0     5000.0           4975.0   36 months   10.65%       162.87     B
# 1     2500.0           2500.0   60 months   15.27%        59.83     C
# 2     2400.0           2400.0   36 months   15.96%        84.33     C
# 3    10000.0          10000.0   36 months   13.49%       339.31     C
# 4     3000.0           3000.0   60 months   12.69%        67.79     B
#
#   sub_grade emp_length home_ownership  annual_inc verification_status  \
# 0        B2  10+ years           RENT     24000.0            Verified
# 1        C4   < 1 year           RENT     30000.0     Source Verified
# 2        C5  10+ years           RENT     12252.0        Not Verified
# 3        C1  10+ years           RENT     49200.0     Source Verified
# 4        B5     1 year           RENT     80000.0     Source Verified
#
#      issue_d  loan_status         purpose addr_state    dti  delinq_2yrs  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42535 entries, 0 to 42537
# Data columns (total 35 columns):
# loan_amnt               42535 non-null float64
# funded_amnt_inv         42535 non-null float64
# term                    42535 non-null object
# int_rate                42535 non-null object
# installment             42535 non-null float64
# grade                   42535 non-null object
# sub_grade               42535 non-null object
# emp_length              41423 non-null object
# home_ownership          42535 non-null object
# annual_inc              42531 non-null float64
# verification_status     42535 non-null object
# issue_d                 42535 non-null datetime64[ns]
# loan_status             42535 non-null object
# purpose                 42535 non-null object
# addr_state              42535 non-null object
# dti                     42535 non-null float64
# delinq_2yrs             42506 non-null float64
# ...

# %%
df[['issue_d','earliest_cr_line','last_pymnt_d','last_credit_pull_d']]
# Out:
#          issue_d earliest_cr_line last_pymnt_d last_credit_pull_d
# 0     2011-12-01       1985-01-01   2015-01-01         2019-05-01
# 1     2011-12-01       1999-04-01   2013-04-01         2016-10-01
# 2     2011-12-01       2001-11-01   2014-06-01         2017-06-01
# 3     2011-12-01       1996-02-01   2015-01-01         2016-04-01
# 4     2011-12-01       1996-01-01   2017-01-01         2018-04-01
# 5     2011-12-01       2004-11-01   2015-01-01         2017-02-01
# 6     2011-12-01       2005-07-01   2016-05-01         2018-12-01
# 7     2011-12-01       2007-01-01   2015-01-01         2014-12-01
# 8     2011-12-01       2004-04-01   2012-04-01         2016-10-01
# 9     2011-12-01       2004-09-01   2012-11-01         2016-12-01
# 10    2011-12-01       1998-01-01   2013-06-01         2018-12-01
# 11    2011-12-01       1989-10-01   2013-09-01         2018-11-01
# 12    2011-12-01       2004-04-01   2012-07-01         2016-10-01
# ...

# %%
df['earliest_cr_line'] = pd.DatetimeIndex(df['earliest_cr_line']).year  
#df['earliest_cr_line']

# %%
#(df['last_pymnt_d']-df['issue_d'])

# %%
df[['issue_d','earliest_cr_line','last_pymnt_d','last_credit_pull_d']].isnull().sum()
# Out:
# issue_d                0
# earliest_cr_line      29
# last_pymnt_d          83
# last_credit_pull_d     4
# dtype: int64

# %%
df[df['last_pymnt_d'].isnull()]
# Out:
#        loan_amnt  funded_amnt_inv        term int_rate  installment grade  \
# 26       15000.0           8725.0   36 months   14.27%       514.64     C
# 2731      8000.0           3975.0   36 months   14.65%       275.96     C
# 3625      6400.0           6400.0   60 months   18.25%       163.39     D
# 3998     18000.0          18000.0   60 months   19.03%       467.23     E
# 4220      1800.0           1800.0   36 months    8.90%        57.16     A
# 4820      1500.0           1500.0   36 months   16.29%        52.96     D
# 5735      2000.0           2000.0   36 months    7.51%        62.23     A
# 6272      1400.0           1400.0   36 months    8.90%        44.46     A
# 6278     30000.0           7100.0   60 months   19.03%       778.72     E
# 6789      4000.0           3975.0   60 months   19.03%       103.83     E
# 6964      4800.0           4800.0   36 months   14.27%       164.69     C
# 6988      2200.0           2200.0   60 months   19.42%        57.58     E
# ...

# %%
df['last_pymnt_d'].fillna(0,inplace=True)

# %%
df['earliest_cr_line'].fillna(df['earliest_cr_line'].median(),inplace=True)

# %%
df[df['last_credit_pull_d'].isnull()]
# Out:
#        loan_amnt  funded_amnt_inv        term int_rate  installment grade  \
# 26094     5000.0           5000.0   36 months   11.12%       163.98     B
# 39545     1000.0            875.0   36 months    7.12%        30.94     A
# 42462     4350.0            825.0   36 months    8.07%       136.45     A
# 42485     4200.0           1350.0   36 months   12.49%       140.48     D
#
#       sub_grade emp_length home_ownership  annual_inc verification_status  \
# 26094        B3    5 years           RENT     96000.0        Not Verified
# 39545        A1   < 1 year       MORTGAGE    120000.0        Not Verified
# 42462        A4   < 1 year           RENT    120000.0        Not Verified
# 42485        D3     1 year           RENT     49500.0        Not Verified
#
#          issue_d                                        loan_status  \
# 26094 2010-09-01                                        Charged Off
# 39545 2007-12-01                                         Fully Paid
# ...

# %%
df['last_credit_pull_d'].fillna(0,inplace=True)

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt_inv        term int_rate  installment grade  \
# 0     5000.0           4975.0   36 months   10.65%       162.87     B
# 1     2500.0           2500.0   60 months   15.27%        59.83     C
# 2     2400.0           2400.0   36 months   15.96%        84.33     C
# 3    10000.0          10000.0   36 months   13.49%       339.31     C
# 4     3000.0           3000.0   60 months   12.69%        67.79     B
#
#   sub_grade emp_length home_ownership  annual_inc verification_status  \
# 0        B2  10+ years           RENT     24000.0            Verified
# 1        C4   < 1 year           RENT     30000.0     Source Verified
# 2        C5  10+ years           RENT     12252.0        Not Verified
# 3        C1  10+ years           RENT     49200.0     Source Verified
# 4        B5     1 year           RENT     80000.0     Source Verified
#
#      issue_d  loan_status         purpose addr_state    dti  delinq_2yrs  \
# ...

# %%
df[df.emp_length.isnull()]
# Out:
#        loan_amnt  funded_amnt_inv        term int_rate  installment grade  \
# 168       2500.0       2500.00000   36 months    7.51%        77.78     A
# 323      18000.0      18000.00000   60 months   17.58%       452.98     D
# 394       4000.0       4000.00000   36 months   11.71%       132.31     B
# 422       1000.0       1000.00000   36 months   14.65%        34.50     C
# 439       8250.0       8250.00000   36 months    7.51%       256.67     A
# 534       1700.0       1700.00000   36 months    7.90%        53.20     A
# 555       5000.0       5000.00000   36 months    8.90%       158.77     A
# 562       3000.0       3000.00000   36 months    9.91%        96.68     B
# 569       8575.0       8575.00000   36 months   17.58%       308.21     D
# 680       5600.0       5600.00000   36 months    6.03%       170.44     A
# 713       6500.0       6500.00000   60 months   14.27%       152.16     C
# 752      14125.0      14125.00000   36 months   12.42%       472.00     B
# ...

# %%
df['emp_length'].fillna(df['emp_length'].mode()[0],inplace=True)

# %%
lst = ['total_acc','pub_rec','open_acc','inq_last_6mths','delinq_2yrs','annual_inc']
for i in lst:
    df[i].fillna(df[i].median(),inplace=True)

# %%
df.pub_rec_bankruptcies.fillna(0,inplace=True)

# %%
df.isnull().sum()
# Out:
# loan_amnt                0
# funded_amnt_inv          0
# term                     0
# int_rate                 0
# installment              0
# grade                    0
# sub_grade                0
# emp_length               0
# home_ownership           0
# annual_inc               0
# verification_status      0
# issue_d                  0
# loan_status              0
# purpose                  0
# addr_state               0
# dti                      0
# delinq_2yrs              0
# earliest_cr_line         0
# inq_last_6mths           0
# open_acc                 0
# pub_rec                  0
# revol_bal                0
# revol_util              90
# total_acc                0
# total_pymnt              0
# total_pymnt_inv          0
# total_rec_prncp          0
# total_rec_int            0
# total_rec_late_fee       0
# recoveries               0
# last_pymnt_d             0
# last_pymnt_amnt          0
# last_credit_pull_d       0
# pub_rec_bankruptcies     0
# ...

# %%
df.revol_util.fillna('0%',inplace=True)

# %%
# Converting string to float
df.revol_util = df.revol_util.apply(lambda x:x[:-1])
#df.revol_util = df.revol_util.astype('float')

# %%
df.revol_util = df.revol_util.astype('float')

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt_inv        term int_rate  installment grade  \
# 0     5000.0           4975.0   36 months   10.65%       162.87     B
# 1     2500.0           2500.0   60 months   15.27%        59.83     C
# 2     2400.0           2400.0   36 months   15.96%        84.33     C
# 3    10000.0          10000.0   36 months   13.49%       339.31     C
# 4     3000.0           3000.0   60 months   12.69%        67.79     B
#
#   sub_grade emp_length home_ownership  annual_inc verification_status  \
# 0        B2  10+ years           RENT     24000.0            Verified
# 1        C4   < 1 year           RENT     30000.0     Source Verified
# 2        C5  10+ years           RENT     12252.0        Not Verified
# 3        C1  10+ years           RENT     49200.0     Source Verified
# 4        B5     1 year           RENT     80000.0     Source Verified
#
#      issue_d  loan_status         purpose addr_state    dti  delinq_2yrs  \
# ...

# %%
df.to_csv('pre_processed.csv')
